# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/Research/Revisiting-Reverse-Distillation/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install geomloss
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## After downloading MVTEC Dataset, unzip and start training

# %%
# !cp '/content/drive/MyDrive/Research/Revisiting-Reverse-Distillation/mvtec_anomaly_detection.tar.xz' '/content/'

# %%
import shutil
shutil.unpack_archive("/content/mvtec_anomaly_detection.tar.xz", "/content/")

# %% [markdown]
# ## Start training on MVTEC dataset
# ### Training/testing on 'carpet', 'leather'

# %%
# !python train_test.py --save_folder RD++ \
                 --classes carpet leather

# %% [markdown]
# ## Only testing with the checkpoints

# %%
# !python inference_checkpoints.py --checkpoint_folder RD++ \
                --classes carpet leather
