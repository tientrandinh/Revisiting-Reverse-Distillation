# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Clone repo and install dependencies

# %%
# !git clone https://github.com/tientrandinh/Revisiting-Reverse-Distillation.git
# Out:
# Cloning into 'Revisiting-Reverse-Distillation'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 59 (delta 14), reused 44 (delta 12), pack-reused 0
# Unpacking objects: 100% (59/59), 2.53 MiB | 3.24 MiB/s, done.

# %%
# %cd ./Revisiting-Reverse-Distillation
# Out:
# /content/drive/MyDrive/Revisiting-Reverse-Distillation

# %%
# !pip install geomloss
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geomloss
#   Downloading geomloss-0.2.6.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from geomloss) (1.22.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from geomloss) (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->geomloss) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->geomloss) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->geomloss) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->geomloss) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->geomloss) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->geomloss) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->geomloss) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->geomloss) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->geomloss) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->geomloss) (1.3.0)
# Building wheels for collected packages: geomloss
#   Building wheel for geomloss (setup.py) ... done
#   Created wheel for geomloss: filename=geomloss-0.2.6-py3-none-any.whl size=32245 sha256=7b659ec3ebaef80ee146011e2ea3e7f7a37d686386435640cd98a1339120723a
#   Stored in directory: /root/.cache/pip/wheels/0d/c9/80/4387eb03aa215ae557869d6fe8be498fd3d3cf297db2357b67
# Successfully built geomloss
# Installing collected packages: geomloss
# Successfully installed geomloss-0.2.6

# %% [markdown]
# ## After downloading MVTEC Dataset, unzip and start training

# %%
# !cp '/content/drive/MyDrive/Revisiting-Reverse-Distillation/mvtec_anomaly_detection.tar.xz' '/content/'

# %%
import shutil
shutil.unpack_archive("/content/mvtec_anomaly_detection.tar.xz", "/content/")

# %% [markdown]
# ## Start training on MVTEC dataset
# ### Training/testing on 'carpet', 'leather'

# %%
# !python main.py --save_folder RD++ \
                --classes carpet leather
# Out:
# Training with classes:  ['carpet', 'leather']
# carpet
# Downloading: "https://download.pytorch.org/models/wide_resnet50_2-95faca4d.pth" to /root/.cache/torch/hub/checkpoints/wide_resnet50_2-95faca4d.pth
# 100% 132M/132M [00:00<00:00, 245MB/s]
# with class carpet, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 1.0000, Pixel Auroc:0.9899, Pixel Aupro: 0.9708
#  10% 1/10 [02:00<18:02, 120.26s/it]Epoch 2, Sample Auroc: 1.0000, Pixel Auroc:0.9916, Pixel Aupro: 0.9759
#  20% 2/10 [03:42<14:36, 109.51s/it]Epoch 3, Sample Auroc: 1.0000, Pixel Auroc:0.9920, Pixel Aupro: 0.9774
#  30% 3/10 [05:23<12:21, 105.86s/it]Epoch 4, Sample Auroc: 1.0000, Pixel Auroc:0.9923, Pixel Aupro: 0.9776
#  40% 4/10 [07:02<10:18, 103.09s/it]Epoch 5, Sample Auroc: 1.0000, Pixel Auroc:0.9923, Pixel Aupro: 0.9777
#  50% 5/10 [08:41<08:27, 101.54s/it]Epoch 6, Sample Auroc: 1.0000, Pixel Auroc:0.9923, Pixel Aupro: 0.9774
#  60% 6/10 [10:22<06:45, 101.25s/it]Epoch 7, Sample Auroc: 1.0000, Pixel Auroc:0.9923, Pixel Aupro: 0.9778
#  70% 7/10 [11:59<04:59, 99.89s/it] Epoch 8, Sample Auroc: 0.9984, Pixel Auroc:0.9922, Pixel Aupro: 0.9781
#  80% 8/10 [13:37<03:18, 99.45s/it]Epoch 9, Sample Auroc: 0.9980, Pixel Auroc:0.9922, Pixel Aupro: 0.9776
#  90% 9/10 [15:16<01:39, 99.29s/it]Epoch 10, Sample Auroc: 0.9972, Pixel Auroc:0.9920, Pixel Aupro: 0.9776
# 100% 10/10 [16:51<00:00, 101.19s/it]
# Best score of class: carpet, Auroc sample: 1.0000, Auroc pixel:0.9923, Pixel Aupro: 0.9778
# leather
# with class leather, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 1.0000, Pixel Auroc:0.9925, Pixel Aupro: 0.9887
#  10% 1/10 [01:37<14:39, 97.78s/it]Epoch 2, Sample Auroc: 1.0000, Pixel Auroc:0.9941, Pixel Aupro: 0.9918
#  20% 2/10 [03:09<12:33, 94.23s/it]Epoch 3, Sample Auroc: 1.0000, Pixel Auroc:0.9940, Pixel Aupro: 0.9917
#  30% 3/10 [04:40<10:50, 92.86s/it]Epoch 4, Sample Auroc: 1.0000, Pixel Auroc:0.9941, Pixel Aupro: 0.9919
#  40% 4/10 [06:09<09:08, 91.33s/it]Epoch 5, Sample Auroc: 1.0000, Pixel Auroc:0.9942, Pixel Aupro: 0.9916
#  50% 5/10 [07:42<07:39, 91.85s/it]Epoch 6, Sample Auroc: 1.0000, Pixel Auroc:0.9943, Pixel Aupro: 0.9915
#  60% 6/10 [09:10<06:02, 90.65s/it]Epoch 7, Sample Auroc: 1.0000, Pixel Auroc:0.9944, Pixel Aupro: 0.9916
#  70% 7/10 [10:38<04:29, 89.70s/it]Epoch 8, Sample Auroc: 1.0000, Pixel Auroc:0.9944, Pixel Aupro: 0.9917
#  80% 8/10 [12:08<02:59, 89.75s/it]Epoch 9, Sample Auroc: 1.0000, Pixel Auroc:0.9943, Pixel Aupro: 0.9915
#  90% 9/10 [13:37<01:29, 89.69s/it]Epoch 10, Sample Auroc: 1.0000, Pixel Auroc:0.9944, Pixel Aupro: 0.9915
# 100% 10/10 [15:06<00:00, 90.64s/it]
# Best score of class: leather, Auroc sample: 1.0000, Auroc pixel:0.9944, Pixel Aupro: 0.9917

# %% [markdown]
# ## Testing with the checkpoints

# %%
# !python inference.py --checkpoint_folder RD++ \
                     --classes carpet leather
# Out:
# carpet: Sample Auroc: 1.0000, Pixel Auroc:0.9923, Pixel Aupro: 0.9778
# leather: Sample Auroc: 1.0000, Pixel Auroc:0.9944, Pixel Aupro: 0.9917
